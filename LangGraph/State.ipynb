# %%
# %load_ext dotenv
# %dotenv
# Out:
# The dotenv extension is already loaded. To reload it, use:
#   %reload_ext dotenv

# %%
from langgraph.graph import START, END, StateGraph
from typing_extensions import TypedDict
from langchain_openai.chat_models import ChatOpenAI
from langchain_core.messages import HumanMessage, BaseMessage
from langchain_core.runnables import Runnable
from collections.abc import Sequence

# %%
class State(TypedDict):
    messages : Sequence[BaseMessage]

# %%
state = State(messages=[HumanMessage("Suggest me some topics to build in Python")])

# %%
state['messages'][0].pretty_print()
# Out:
# ================================ Human Message =================================
#
# Hello Python!

# %%
type(state)
# Out:
# dict

# %% [markdown]
# # Defining the node

# %%
chat = ChatOpenAI(
    model = "gpt-4o",
    seed = 365,
    temperature = 0,
    max_completion_tokens = 100
)

# %%
# A node is just a user defined method that gets executed

def chatbot(state: state) -> State:
    response = chat.invoke(state['messages'])
    response.pretty_print()
    return State(messages=[response])

# %%
response = chatbot(state)
# Out:
# ================================== Ai Message ==================================
#
# Certainly! Here are some project ideas across various domains that you can build using Python:
#
# 1. **Web Development:**
#    - **Blog Platform:** Create a simple blogging platform using Flask or Django.
#    - **Portfolio Website:** Build a personal portfolio website to showcase your projects and skills.
#    - **E-commerce Site:** Develop a basic e-commerce site with product listings, a shopping cart, and checkout functionality.
#
# 2. **Data Science and Machine Learning:**
#    - **Data Analysis Tool:**
